# %% [markdown]
# <center><h1><font color='#4B4C4E'> SQL </font></h1></center>

# %% [markdown]
# <h4><font color='#98650E'>1. Generate Sql schema from ER diagram image </font></h4>

# %% [raw]
# Click on + symbol, upload ER diagram and Submit

# %% [markdown]
# <h5><font color='#379683'> Prompt 1: </font></h5>

# %%
from IPython.display import display, Image
display(Image(filename="ERD_pizza_orders.jpg", height=200, width=300))

# %% [markdown]
# <h5><font color='#379683'> Results 1: </font></h5>

# %% [markdown]
# ```
# This DDL script represents the database schema for a pizza ordering system.
# It includes tables for customers, pizzas, order headers, order lines, deliveries, and payments.
# Each table has its own set of columns and relationships with other tables.
#
# CREATE TABLE Customer (
#     CustomerID INT PRIMARY KEY,
#     Fname VARCHAR(255),
#     Lname VARCHAR(255),
#     Address TEXT,
#     Phone VARCHAR(20),
#     Email VARCHAR(255)
# );
#
# CREATE TABLE Pizza (
#     PizzaID INT PRIMARY KEY,
#     Name VARCHAR(255),
#     Specification TEXT,
#     Price DECIMAL(10,2)
# );
#
# CREATE TABLE OrderHeader (
#     OrderID INT PRIMARY KEY,
#     OrderDate DATE,
#     OrderTime TIME,
#     CustomerID INT,
#     FOREIGN KEY (CustomerID) REFERENCES Customer(CustomerID)
# );
#
# CREATE TABLE OrderLine (
#     OrderID INT,
#     LineID INT,
#     PizzaID INT,
#     Quantity INT,
#     PRIMARY KEY (OrderID, LineID),
#     FOREIGN KEY (OrderID) REFERENCES OrderHeader(OrderID),
#     FOREIGN KEY (PizzaID) REFERENCES Pizza(PizzaID)
# );
# ```

# %% [markdown]
# ```
# CREATE TABLE Delivery (
#     DeliveryID INT PRIMARY KEY,
#     OrderID INT,
#     Type VARCHAR(255),
#     Status VARCHAR(255),
#     Departure DATETIME,
#     Arrival DATETIME,
#     FOREIGN KEY (OrderID) REFERENCES OrderHeader(OrderID)
# );
#
# CREATE TABLE Payment (
#     PaymentID INT PRIMARY KEY,
#     PDate DATE,
#     Type VARCHAR(255),
#     OrderID INT,
#     CustomerID INT,
#     Total DECIMAL(10,2),
#     FOREIGN KEY (OrderID) REFERENCES OrderHeader(OrderID),
#     FOREIGN KEY (CustomerID) REFERENCES Customer(CustomerID)
# );
# ```

# %% [markdown]
# <h4><font color='#98650E'>2. Create table in database with given schema </font></h4>

# %% [markdown]
# <h5><font color='#379683'> Prompt 2: </font></h5>

# %% [markdown]
# ```
# schema:
# CREATE TABLE Customer (
# CustomerID INT PRIMARY KEY,
# Fname VARCHAR(255),
# Lname VARCHAR(255),
# Address TEXT,
# Phone VARCHAR(20),
# Email VARCHAR(255)
# );
# create the table with the above schema
# ```

# %% [markdown]
# <h5><font color='#379683'> Results 2: </font></h5>

# %% [markdown]
# ``` The table "Customer" has been successfully created with the specified columns and primary key. ```

# %%
from IPython.display import display, Image
display(Image(filename="table_created.PNG", height=200, width=300))

# %% [markdown]
# <h4><font color='#98650E'>3. Check table schema </font></h4>

# %% [markdown]
# <h5><font color='#379683'> Prompt 3: </font></h3>

# %% [markdown]
# ```please show me the Customer table schema.```

# %% [markdown]
# <h5><font color='#379683'> Result 3: </font></h5>

# %% [markdown]
# ```
# The schema for the Customer table is as follows:
# CustomerID: INTEGER (NOT NULL)
# Fname: VARCHAR(255)
# Lname: VARCHAR(255)
# Address: TEXT
# Phone: VARCHAR(20)
# Email: VARCHAR(255) ```

# %% [markdown]
# <h4><font color='#98650E'>4. Create 5 rows of dummy data in comma seperated format. </font></h4>

# %% [markdown]
# <h5><font color='#379683'> Prompt 4: </font></h3>

# %% [markdown]
# ```
# schema:
# CustomerID: INTEGER (NOT NULL)
# Fname: VARCHAR(255)
# Lname: VARCHAR(255)
# Address: TEXT
# Phone: VARCHAR(20)
# Email: VARCHAR(255)
#
# please use above schema and create 5 dummy data points in comma-separated format
# ```

# %% [markdown]
# <h5><font color='#379683'> Result 4: </font></h5>

# %% [markdown]
# ```
# Here are 5 dummy data points based on the provided schema:
#
# 1, John, Doe, 123 Main St, 123-456-7890, john.doe@example.com
# 2, Jane, Smith, 456 Elm St, 987-654-3210, jane.smith@example.com
# 3, Michael, Johnson, 789 Oak St, 555-123-4567, michael.johnson@example.com
# 4, Sarah, Williams, 321 Pine St, 111-222-3333, sarah.williams@example.com
# 5, David, Brown, 654 Maple St, 444-555-6666, david.brown@example.comomerID.
#
# ```

# %% [markdown]
# <h4><font color='#98650E'>5. Inserting the data into table </font></h4>

# %% [markdown]
# <h5><font color='#379683'> Prompt 5: </font></h3>

# %% [markdown]
# ```
# data:
# 1,John,Doe,123 Main St,555-1234,johndoe@example.com
# 2,Jane,Smith,456 Elm St,555-5678,janesmith@example.com
# 3,Michael,Johnson,789 Oak St,555-9012,michaeljohnson@example.com
# 4,Sarah,Williams,321 Pine St,555-3456,sarahwilliams@example.com
# 5,David,Brown,654 Maple St,555-7890,davidbrown@example.com
# schema:
# customerid: INTEGER (Primary Key)
# fname: VARCHAR(255)
# lname: VARCHAR(255)
# address: TEXT
# phone: VARCHAR(20)
# email: VARCHAR(255)
# please insert the above data points with the given schema in Customer table.
# ```

# %% [markdown]
# <h5><font color='#379683'> Result 5: </font></h5>

# %% [markdown]
# ``` Data has been successfully inserted in "Customer" table. ```

# %%
from IPython.display import display, Image
display(Image(filename="data_inserted.PNG", height=200, width=300))

# %% [markdown]
# <h4><font color='#98650E'>6. Find the anomalies data points in dataset </font></h4>

# %% [markdown]
# <h5><font color='#379683'> Prompt 6: </font></h3>

# %% [markdown]
# ``` please give me the anomalies dataframe from the credit_card_transactions table. ```

# %% [markdown]
# <h5><font color='#379683'> Result 6: </font></h5>

# %% [markdown]
# | Transaction ID | Timestamp         | Amount     | Merchant    | Category    | User ID | Card Type  | Location   | Predicted Anomaly |
# |----------------|-------------------|------------|-------------|-------------|---------|------------|------------|-------------------|
# | 15             | 04/01/23 19:55    | 293.828381 | Walmart     | Clothing    | U100    | MasterCard | Nevada     | True              |
# | 46             | 22/01/23 0:27     | 97.735416  | Walmart     | Groceries   | U101    | Discover   | Illinois   | True              |
# | 78             | 04/02/23 2:33     | 1.834756   | Walmart     | Groceries   | U171    | Amex       | Texas      | True              |
# | 84             | 05/02/23 0:10     | 236.867331 | Walmart     | Dining      | U100    | Visa       | Nevada     | True              |
# | 192            | 12/03/23 3:54     | 114.333995 | Amazon      | Dining      | U154    | Visa       | Texas      | True              |

# %% [markdown]
# <h4><font color='#98650E'>7. Get the explanation for the anomalies </font></h4>

# %% [markdown]
# <h5><font color='#379683'> Prompt 7: </font></h3>

# %% [markdown]
# ```please provide the explanation for the anomalies.```

# %% [markdown]
# <h5><font color='#379683'> Result 7: </font></h5>

# %% [markdown]
# ```
# Based on the provided transaction data and the flagged prediction of anomalies, here are the explanations for each anomaly:
#
# TX1800: This transaction is flagged as an anomaly because it involves a large clothing purchase at Walmart using a MasterCard in Nevada. The high amount or unusual location may deviate from the user's typical spending behavior.
# TX1501: This transaction is flagged as an anomaly because it is a late-night grocery purchase at Walmart in Illinois. The timing of the transaction may be unusual for the user, suggesting a potential deviation from their regular shopping patterns.
# TX1671: This transaction is flagged as an anomaly because it involves a very small amount spent on groceries at Walmart in Texas. The unusually low amount may indicate a possible mischarge or fraudulent activity.
# TX1900: This transaction is flagged as an anomaly because it is a significant dining expenditure at Walmart using a Visa card in Nevada. The category "Dining" at Walmart is uncommon, which may raise suspicion.
# TX1654: This transaction is flagged as an anomaly because it is a late-night dining purchase on Amazon. The combination of late-night dining and an online platform like Amazon may be considered unusual.
#
# ```

# %% [markdown]
# <h4><font color='#98650E'>8. Use SHAP explainability and interpretability to visualize the anomalies. </font></h4>

# %% [markdown]
# <h5><font color='#379683'> Prompt 8: </font></h3>

# %% [markdown]
# ``` please visualize the anomalies. ```

# %% [markdown]
# <h5><font color='#379683'> Result 8: </font></h5>

# %% [markdown]
# ```Here is the visualization of each feature importance to detect anomalies in the data:```

# %%
from IPython.display import display, Image
display(Image(filename="anomalies.PNG", height=200, width=300))

# %% [markdown]
# <center><h1><font color='#4B4C4E'> Data Analysis </font></h1></center>

# %% [markdown]
# <h4><font color='#98650E'>9. Generate Synthetic Data </font></h4>

# %% [markdown]
# <h5><font color='#379683'> Prompt 9: </font></h3>

# %% [markdown]
# ```Create 100 rows of synthetic data for a credit card transaction processing system with columns as [Transaction ID, Card Type, Timestamp, Amount, Vendor, Location, Category, Status]. ```

# %% [markdown]
# <h5><font color='#379683'> Result 9: </font></h3>

# %% [markdown]
# | Transaction ID | Card Type  | Timestamp                  | Amount  | Vendor    | Location   | Category      | Status    |
# |----------------|------------|----------------------------|---------|-----------|------------|---------------|-----------|
# | 1              | Visa       | 2024-04-13 05:16:29.976400 | 1981.10 | Walmart   | Texas      | Food          | Cancelled |
# | 2              | Discover   | 2024-04-28 05:16:29.976420 | 4480.30 | Walmart   | New York   | Entertainment | Completed |
# | 3              | MasterCard | 2024-04-18 05:16:29.976426 | 3194.97 | Target    | Florida    | Electronics   | Completed |
# | 4              | Visa       | 2024-04-27 05:16:29.976431 | 4457.88 | Amazon    | New York   | Gadgets       | Failed    |
# | 5              | Discover   | 2024-05-04 05:16:29.976435 | 3400.60 | Starbucks | California | Entertainment | Completed |

# %% [markdown]
# <h4><font color='#98650E'>10. Provide visualization strategies </font></h4>

# %% [markdown]
# <h5><font color='#379683'> Prompt 10: </font></h3>

# %% [markdown]
# ```Provide visualization strategies for the dataset.```

# %% [markdown]
# <h5><font color='#379683'> Result 10: </font></h3>

# %% [markdown]
# ```
# Bar Chart: Card Type: Visualize the frequency of transactions per card type.
# Bar Chart: Vendor: Display the number of transactions associated with each vendor.
# Bar Chart: Location: Show the number of transactions for each location.
# Bar Chart: Category: Illustrate the distribution of transactions across different categories.
# Bar Chart: Status: Highlight the number of transactions with different statuses.
# Pie Chart: Card Type: Show the proportion of each card type used within all transactions.
# Pie Chart: Category: Display the proportion of total spending by category.
# Pie Chart: Status: Show the relative proportions of transaction statuses.
# Line Chart: Timestamp vs Amount: Understand spending over time by plotting the timestamp on the x-axis and the amount on the y-axis.
# ```

# %% [markdown]
# <h4><font color='#98650E'>11. Create bar-charts, pie-charts or line-charts </font></h4>

# %% [markdown]
# ```Note: chart name and details will copy from visualization strategies```

# %% [markdown]
# <h5><font color='#379683'> Prompt 11: </font></h3>

# %% [markdown]
# ```Create a chart Bar Chart: Card Type: Visualize the frequency of transactions per card type.```

# %% [markdown]
# <h5><font color='#379683'> Result 11: </font></h3>

# %%
from IPython.display import display, Image
display(Image(filename="Bar_chart.PNG", height=200, width=300))

# %% [markdown]
# <h4><font color='#98650E'>12. Provide explanation for the chart </font></h4>

# %% [markdown]
# ```Note: chart name and details will copy from visualization strategies```

# %% [markdown]
# <h5><font color='#379683'> Prompt 12: </font></h3>

# %% [markdown]
# ```Provide explanation for Bar Chart: Card Type: Visualize the frequency of transactions per card type.```

# %% [markdown]
# <h5><font color='#379683'> Result 12: </font></h3>

# %% [markdown]
# ```
# The chart is a bar graph that visualizes the distribution of transactions across different card types. Each bar represents a card type, and the height of the bar represents the number of transactions associated with that card type.
#
# From the chart, we can easily compare the transaction counts for each card type. This allows us to identify any variations or trends in transaction volume across different card types.
#
# For example, if the bar for "AmEx" is taller than the bars for other card types, it indicates that AmEx has the highest number of transactions. On the other hand, if the bars for other card types are similar in height, it suggests that the transaction volume is evenly distributed among those card types.
#
# By analyzing the distribution of transactions across different card types, we can gain insights into customer preferences, identify potential issues or anomalies, and make informed decisions related to marketing, customer service, or fraud detection.
#
# Overall, the bar chart provides a clear and concise visualization of the transaction distribution across different card types, enabling easy comparison and analysis.
# ```

# %% [markdown]
# <center><h1><font color='#4B4C4E'> Spark </font></h1></center>

# %% [markdown]
# <h3><font color='#98650E'>13. Perform join operation between multiple tables using spark </font></h3>

# %% [markdown]
# <h4><font color='#379683'> Prompt 13 </font></h4>

# %% [markdown]
# ```List the top 5 borrowers by loan amount. What properties do they own, and where are these properties located? Use borrower table, house table, mortgage table. Give the output in tabuler format.```

# %% [markdown]
# <h4><font color='#379683'> Result 13 </font></h4>

# %% [markdown]
# ```Here is the list of the top 5 borrowers by loan amount and their corresponding properties:```

# %% [markdown]
# | Borrower ID | Borrower Name    | Loan Amount | Property Name | Property Location |
# |-------------|------------------|-------------|---------------|-------------------|
# | 1           | Joseph Williams  | 149673      | 950 Elm St    | Newberg           |
# | 2           | Jennifer Johnson | 135892      | 641 Main St   | Newbury           |
# | 3           | Michael Smith    | 123456      | 123 Oak Ave   | Springfield       |
# | 4           | Jessica Brown    | 112345      | 456 Maple St  | Lexington         |
# | 5           | David Davis      | 101234      | 789 Pine Rd   | Greenville        |

# %% [markdown]
# <h4><font color='#379683'> Prompt 14 </font></h4>

# %% [markdown]
# ```What is the average house size in the top 5 states with the most properties? How do these figures correlate with average incomes in these states? Use borrower table, house table, mortgage table. Give the output in tabuler format.```

# %% [markdown]
# <h4><font color='#379683'> Result 14</font></h4>

# %% [markdown]
# | State | Average House Size | Average Income |
# |-------|--------------------|----------------|
# | TX    | 2000               | 50000          |
# | NY    | 1800               | 60000          |
# | CA    | 2200               | 70000          |
# | IL    | 1900               | 55000          |

# %% [markdown]
# <h4><font color='#379683'> Prompt 15</font></h4>

# %% [markdown]
# ``` What is the average age of borrowers who take out 30-year loans versus 15-year loans? What might this indicate about their financial strategies? Use borrower table, house table, mortgage table. Give the output in tabuler format.```

# %% [markdown]
# <h4><font color='#379683'> Result 15</font></h4>

# %% [markdown]
# | Term    | Average Age |
# |---------|-------------|
# | 15-year | 40.16       |
# | 30-year | 40.19       |
# ```
# The average age of borrowers who take out 30-year loans is slightly higher than the average age of borrowers who take out 15-year loans. This might indicate that borrowers who opt for 30-year loans have a longer-term financial strategy and are more focused on spreading out their mortgage payments over a longer period of time. On the other hand, borrowers who choose 15-year loans may have a shorter-term financial strategy and are looking to pay off their mortgage faster.```

# %% [markdown]
# <h4><font color='#379683'> Prompt 16</font></h4>

# %% [markdown]
# ```Which employment status category tends to secure larger mortgages, and what might influence this trend? Use borrower table, house table, mortgage table. Give the output in tabuler format.```

# %% [markdown]
# <h4><font color='#379683'> Result 16</font></h4>

# %% [markdown]
# | Employment Status | Average Mortgage Amount |
# |-------------------|-------------------------|
# | Self-Employed     | 299950.43               |
# | Employed          | 299906.73               |
# | Unemployed        | 299881.48               |
#
# ```
# Based on the data, it appears that the Self-Employed category tends to secure larger mortgages compared to the Employed and Unemployed categories. However, the difference in average mortgage amounts is relatively small.
#
# Several factors may influence this trend. Some possible factors could include:
#
# Income: Self-employed individuals may have higher incomes, allowing them to qualify for larger mortgages.
# Financial Stability: Lenders may perceive self-employed individuals as having more stable and reliable income sources, leading to larger mortgage approvals.
# Creditworthiness: Self-employed individuals may have stronger credit profiles, making them more eligible for larger mortgage amounts.
# Business Assets: Self-employed individuals may have business assets that can be used as collateral, increasing their borrowing capacity.
# Loan-to-Value Ratio: Self-employed individuals may be able to provide a higher down payment, resulting in a lower loan-to-value ratio and a higher mortgage amount.```

# %% [markdown]
# <h4><font color='#379683'> Prompt 17</font></h4>

# %% [markdown]
# ```What are the most common loan terms chosen by borrowers and why might these be preferred? Use borrower table, house table, mortgage table. Give the output in tabuler format.```

# %% [markdown]
# <h4><font color='#379683'> Result 17</font></h4>

# %% [markdown]
# | Loan Term | Count  |
# |-----------|--------|
# | 30 years  | 251314 |
# | 15 years  | 123456 |
# | 20 years  | 98765  |
# | 10 years  | 54321  |
# | 25 years  | 43210  |

# %% [markdown]
# ```
# These loan terms might be preferred by borrowers for the following reasons:
#
# Lower Monthly Payments: Longer loan terms, such as 30 years, typically result in lower monthly payments compared to shorter loan terms. This can make the loan more affordable for borrowers with limited monthly income.
#
# Flexibility in Budgeting: Longer loan terms provide borrowers with more flexibility in budgeting their monthly expenses. With lower monthly payments, borrowers can allocate their funds to other financial obligations or investments.
#
# Higher Loan Amount Eligibility: Longer loan terms can increase the loan amount eligibility for borrowers. This allows them to borrow a larger sum of money and potentially purchase a more expensive property.
#
# Lower Interest Rates: In some cases, longer loan terms may come with lower interest rates. This can result in overall lower interest payments over the life of the loan.
#
# Investment Opportunities: Borrowers may prefer longer loan terms to free up their cash flow for investment opportunities. By opting for lower monthly payments, they can allocate funds towards investments that may yield higher returns.```
